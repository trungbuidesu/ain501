# %% [markdown]
# # Phase 0.4 HMDB Action Explore
#
# Inspect HMDB-51 classes, video manifests, sample frames, and group-aware splits.

# %%
from pathlib import Path

from training.scripts.data_utils import load_yaml

config = load_yaml(Path('../configs/datasets/action_accessibility.yaml'))
config['phase_notes']['approaching']
