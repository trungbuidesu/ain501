# %% [markdown]
# # Phase 0.5 Places Scene Subset
#
# Build a balanced Places365 subset and track custom/proxy scene labels.

# %%
from pathlib import Path

from training.scripts.data_utils import load_yaml

config = load_yaml(Path('../configs/datasets/scene_accessibility.yaml'))
config['classes']
