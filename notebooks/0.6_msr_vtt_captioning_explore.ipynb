# %% [markdown]
# # Phase 0.6 MSR-VTT Captioning Explore
#
# Normalize captions into video_id -> captions[] and inspect caption length stats.

# %%
from pathlib import Path

from training.scripts.data_utils import load_yaml

config = load_yaml(Path('../configs/datasets/video_captioning_msr_vtt.yaml'))
config['format']
