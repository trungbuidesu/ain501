# %% [markdown]
# # Phase 0.7 ICDAR OCR Explore
#
# Parse ICDAR 2015 quadrilateral boxes and handle ignore transcription ###.

# %%
from pathlib import Path

from src.training.scripts.data_utils import load_yaml

config = load_yaml(Path('../configs/datasets/ocr_icdar2015.yaml'))
config['format']
