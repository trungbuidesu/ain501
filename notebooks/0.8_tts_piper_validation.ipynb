# %% [markdown]
# # Phase 0.8 Piper TTS Validation
#
# Validate Vietnamese and English Piper voice files and generated WAV samples.

# %%
from pathlib import Path

from src.training.scripts.data_utils import load_yaml

config_path = Path("../configs/datasets/tts_piper_accessibility.yaml")
config = load_yaml(config_path)
config["voices"]["defaults"].keys()
