# %% [markdown]
# # Phase 0.9 MiDaS Reserved Slot
#
# Document the depth-estimation IO contract. This does not block Phase 0.

# %%
from pathlib import Path

from src.training.scripts.data_utils import load_yaml

config = load_yaml(Path("../configs/datasets/depth_midas_reserved.yaml"))
config["io"]
